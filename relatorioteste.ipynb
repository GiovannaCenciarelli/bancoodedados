# %% [markdown]
# # # * **TESTANDO PUXAR DADOS, USAR O SEABORN E afins**

# %%
# !pip install pytrends

# %%
from pytrends.request import TrendReq

# Conexão com o Google Trends
pytrends = TrendReq(hl='pt-BR', tz=360)

# %%
# Definir os parâmetros de consulta
kw_list = ['/m/03p1r4']  # ID do termo (em vez de uma palavra-chave textual)

# Carregar os dados de tendências
pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='', gprop='')

# Obter os dados de interesse ao longo do tempo
trends_data = pytrends.interest_over_time()

# Exibir os dados
print(trends_data)
# Out:
#             /m/03p1r4  isPartial
# date
# 2004-01-01          5      False
# 2004-02-01          6      False
# 2004-03-01          5      False
# 2004-04-01          5      False
# 2004-05-01          5      False
# ...               ...        ...
# 2024-06-01         30      False
# 2024-07-01         30      False
# 2024-08-01         32      False
# 2024-09-01         32      False
# 2024-10-01         35       True
#
# [250 rows x 2 columns]
# /opt/conda/lib/python3.10/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %% [markdown]
# *Países que mais consultaram o termo CUPCAKE *

# %%
from pytrends.request import TrendReq

# Conexão com o Google Trends
pytrends = TrendReq(hl='pt-BR', tz=360)

# Definir o termo de busca "Cupcake"
kw_list = ['Cupcake']

# Construir o payload para o termo
pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='', gprop='')

# Obter o interesse por país
df = pytrends.interest_by_region(resolution='COUNTRY', inc_low_vol=True, inc_geo_code=False)

# Ordenar os países pelo maior interesse
df = df.sort_values(by='Cupcake', ascending=False)

# Exibir os países que mais pesquisaram o termo "Cupcake"
print(df.head(10))  # Exibe os 10 países que mais pesquisaram
# Out:
#                                  Cupcake
# geoName
# Ilhas Malvinas (Ilhas Falkland)      100
# Brunei                                88
# Palau                                 80
# Austrália                             74
# Trinidad e Tobago                     73
# Bermudas                              71
# Guernsey                              69
# São Cristóvão e Névis                 68
# Ilhas Virgens Britânicas              68
# Jersey                                68

# %% [markdown]
# **10 ESTADOS QUE + PESQUISARAM CUPCAKE**

# %%
# Construir o payload para o termo filtrando por Brasil
pytrends.build_payload(kw_list, cat=0, timeframe='all', geo='BR', gprop='')

# Obter o interesse por estados dentro do Brasil
df_brasil = pytrends.interest_by_region(resolution='REGION', inc_low_vol=True, inc_geo_code=False)

# Ordenar os estados brasileiros pelo maior interesse
df_brasil = df_brasil.sort_values(by='Cupcake', ascending=False)

# Exibir os estados que mais pesquisaram o termo no Brasil
print(df_brasil.head(10))  # Exibe os 10 estados que mais pesquisaram
# Out:
#                     Cupcake
# geoName
# Rio de Janeiro          100
# Pernambuco               87
# Rio Grande do Sul        84
# São Paulo                82
# Pará                     76
# Espírito Santo           76
# Paraná                   73
# Alagoas                  73
# Santa Catarina           72
# Mato Grosso do Sul       71

# %% [markdown]
# *mas e a análise cupckaniana, então, plotaremos um belo gráfico*

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# Conexão com o Google Trends
pytrends = TrendReq(hl='pt-BR', tz=360)

# Definir o termo de busca "Cupcakes"
kw_list = ['cupcakes']

# Reduzir o timeframe para os últimos 5 anos e simplificar os parâmetros
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='BR', gprop='')

# Obter os dados de interesse ao longo do tempo
trends_data = pytrends.interest_over_time()

# Verificar se os dados contêm uma coluna 'isPartial' e remover
if 'isPartial' in trends_data.columns:
    trends_data = trends_data.drop(columns=['isPartial'])

# Plotar o gráfico
plt.figure(figsize=(10,6))
plt.plot(trends_data.index, trends_data['cupcakes'], label='Cupcakes')

# Configurações do gráfico
plt.title('Interesse por Cupcakes no Brasil (últimos 5 anos)')
plt.xlabel('Ano')
plt.ylabel('Volume de pesquisa')
plt.grid(True)
plt.legend(loc='upper right')

# Exibir o gráfico
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %% [markdown]
# PARECE QUE OS CJUPCAKES NÃO ESTÃO TÃO EM ALTA, agora, veremos os donos da bola, O PISTACHE

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# Conexão com o Google Trends
pytrends = TrendReq(hl='pt-BR', tz=360)

# Definir o termo de busca "Cupcakes"
kw_list = ['pistache']

# Reduzir o timeframe para os últimos 5 anos e simplificar os parâmetros
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='BR', gprop='')

# Obter os dados de interesse ao longo do tempo
trends_data = pytrends.interest_over_time()

# Verificar se os dados contêm uma coluna 'isPartial' e remover
if 'isPartial' in trends_data.columns:
    trends_data = trends_data.drop(columns=['isPartial'])

# Plotar o gráfico
plt.figure(figsize=(10,6))
plt.plot(trends_data.index, trends_data['pistache'], label='pistache')

# Configurações do gráfico
plt.title('Interesse por pistaches no Brasil (últimos 5 anos)')
plt.xlabel('Ano')
plt.ylabel('Volume de pesquisa')
plt.grid(True)
plt.legend(loc='upper right')

# Exibir o gráfico
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %% [markdown]
# ORA, parece QUE O PISTACHE VEIO COM TUDO, a mais nvoa tendência da middle class br .
# AGORA, MUDANDO DE ASSUNTO, PESQUISAREMOS A **DOUTORA DEOLANE BEZERRA**.

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# Conexão com o Google Trends
pytrends = TrendReq(hl='pt-BR', tz=360)

# Definir o termo de busca "Cupcakes"
kw_list = ['Deolane Bezerra']

# Reduzir o timeframe para os últimos 5 anos e simplificar os parâmetros
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='BR', gprop='')

# Obter os dados de interesse ao longo do tempo
trends_data = pytrends.interest_over_time()

# Verificar se os dados contêm uma coluna 'isPartial' e remover
if 'isPartial' in trends_data.columns:
    trends_data = trends_data.drop(columns=['isPartial'])

# Plotar o gráfico
plt.figure(figsize=(10,6))
plt.plot(trends_data.index, trends_data['Deolane Bezerra'], label='Deolane Bezerra')

# Configurações do gráfico
plt.title('Interesse por Deolane Bezerras no Brasil (últimos 7 anos)')
plt.xlabel('Ano')
plt.ylabel('Volume de pesquisa')
plt.grid(True)
plt.legend(loc='upper right')

# Exibir o gráfico
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %% [markdown]
# *COMO PODEMOS VER, A DOUTORA DEOLANE, foi uma febre NO 2° SEMESTRE DE 2024. AI ESTÁ A DOUTORA DEOLANE*

# %% [markdown]
# AGORA, VAMOS VER COMO A DOUTORA DEOLANE AFETOU A BOLSA DE NOVA YORK

# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.5/939.5 kB 10.8 MB/s eta 0:00:00
# done
# done
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 4.3 MB/s eta 0:00:00
# ...
# done
#   Created wheel for peewee: filename=peewee-3.17.7-cp310-cp310-linux_x86_64.whl size=317857 sha256=f6ddc6b69e0d06f623387145f8ea34f39f0fe7b27a55fad20f2d81f80d749bd1
#   Stored in directory: /root/.cache/pip/wheels/8d/0e/f8/48eb93a200fca4c502d7590613616fa4d2c9533f7308f9e28a
# Successfully built peewee
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# 1. Data da prisão da Doutora Deolane Bezerra (exemplo: 5 de outubro de 2023)
prison_date = '2023-10-05'

# 2. Coletar dados da Bolsa de Nova York (usando S&P 500 como exemplo)
# Obter dados do índice S&P 500 para os 30 dias antes e depois da data da prisão
start_date = '2023-09-05'
end_date = '2023-11-05'
sp500 = yf.download('^GSPC', start=start_date, end=end_date)

# 3. Adicionar uma coluna para identificar a data da prisão
sp500['Prison'] = sp500.index.map(lambda x: 1 if str(x.date()) == prison_date else 0)

# 4. Plotar os dados
plt.figure(figsize=(12, 6))

# Gráfico do S&P 500
plt.plot(sp500.index, sp500['Close'], label='S&P 500', color='blue')

# Marcar a data da prisão
plt.axvline(pd.to_datetime(prison_date), color='red', linestyle='--', label='Prisão da Doutora Deolane Bezerra')

# Configurações do gráfico
plt.title('Relação entre a Prisão da Doutora Deolane Bezerra e o S&P 500')
plt.xlabel('Data')
plt.ylabel('Valor de Fechamento do S&P 500')
plt.legend()
plt.grid()

# Exibir o gráfico
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # > a prisão de doutora deolane não foi suficiente para destruir o capitalismo.
